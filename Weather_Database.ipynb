# %%
# Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Generate 2,000 random lat/long coordinates

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %% [markdown]
# ### Unpack our lat_lngs zip object into a list

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %% [markdown]
# ### Populate list of unique cities

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %% [markdown]
# ### Create URL for API call to OpenWeatherMap

# %%
# Import the requests library.
import requests

# Import the API key.
from config import open_weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + open_weather_api_key

# %%
############
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


############
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})                    
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | chatra
# Processing Record 3 of Set 1 | wanlaweyn
# Processing Record 4 of Set 1 | mehamn
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | mar del plata
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | pleshanovo
# Processing Record 12 of Set 1 | moiyabana
# City not found. Skipping...
# Processing Record 13 of Set 1 | kerki
# City not found. Skipping...
# Processing Record 14 of Set 1 | cabo san lucas
# Processing Record 15 of Set 1 | hithadhoo
# Processing Record 16 of Set 1 | kaeo
# Processing Record 17 of Set 1 | shahrud
# Processing Record 18 of Set 1 | sorland
# Processing Record 19 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 20 of Set 1 | road town
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | pierre
# Processing Record 23 of Set 1 | nikolskoye
# Processing Record 24 of Set 1 | inongo
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | provideniya
# Processing Record 27 of Set 1 | baruun-urt
# Processing Record 28 of Set 1 | aktau
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | emerald
# Processing Record 31 of Set 1 | castro
# Processing Record 32 of Set 1 | lebu
# Processing Record 33 of Set 1 | price
# Processing Record 34 of Set 1 | thompson
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | hobart
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | port blair
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | majene
# Processing Record 42 of Set 1 | bonavista
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | chicama
# Processing Record 45 of Set 1 | salalah
# Processing Record 46 of Set 1 | pevek
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | iranshahr
# Processing Record 49 of Set 1 | hasaki
# Processing Record 50 of Set 1 | moroto
# Processing Record 1 of Set 2 | aschersleben
# Processing Record 2 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 3 of Set 2 | rikitea
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | margate
# Processing Record 6 of Set 2 | taldan
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | gat
# Processing Record 9 of Set 2 | barrow
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 2 | inirida
# Processing Record 15 of Set 2 | kang
# Processing Record 16 of Set 2 | nanortalik
# Processing Record 17 of Set 2 | srednekolymsk
# Processing Record 18 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 2 | bethel
# Processing Record 20 of Set 2 | albany
# Processing Record 21 of Set 2 | guaruja
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | qaanaaq
# Processing Record 24 of Set 2 | san carlos de bariloche
# Processing Record 25 of Set 2 | eagle pass
# Processing Record 26 of Set 2 | masuguru
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | berlevag
# Processing Record 29 of Set 2 | cohoes
# Processing Record 30 of Set 2 | castellarano
# Processing Record 31 of Set 2 | saldanha
# Processing Record 32 of Set 2 | luderitz
# Processing Record 33 of Set 2 | busselton
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | avera
# Processing Record 37 of Set 2 | buala
# Processing Record 38 of Set 2 | borisovka
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | seymchan
# Processing Record 41 of Set 2 | goderich
# Processing Record 42 of Set 2 | richards bay
# Processing Record 43 of Set 2 | garowe
# Processing Record 44 of Set 2 | tura
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | trapani
# Processing Record 47 of Set 2 | half moon bay
# Processing Record 48 of Set 2 | cayenne
# Processing Record 49 of Set 2 | hanmer springs
# Processing Record 50 of Set 2 | vilhena
# Processing Record 1 of Set 3 | shingu
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | zhigansk
# Processing Record 4 of Set 3 | hammerfest
# Processing Record 5 of Set 3 | west wendover
# Processing Record 6 of Set 3 | saint-philippe
# Processing Record 7 of Set 3 | lompoc
# Processing Record 8 of Set 3 | kapaa
# Processing Record 9 of Set 3 | jiwani
# Processing Record 10 of Set 3 | upernavik
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | irbeyskoye
# Processing Record 13 of Set 3 | longyearbyen
# Processing Record 14 of Set 3 | muscat
# Processing Record 15 of Set 3 | port elizabeth
# Processing Record 16 of Set 3 | rio grande
# Processing Record 17 of Set 3 | puerto de la cruz
# Processing Record 18 of Set 3 | xingcheng
# Processing Record 19 of Set 3 | san ramon
# Processing Record 20 of Set 3 | safaga
# Processing Record 21 of Set 3 | chuy
# Processing Record 22 of Set 3 | namibe
# Processing Record 23 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 24 of Set 3 | oyama
# Processing Record 25 of Set 3 | portland
# Processing Record 26 of Set 3 | itupiranga
# Processing Record 27 of Set 3 | ribeira grande
# Processing Record 28 of Set 3 | sovetskaya gavan
# Processing Record 29 of Set 3 | lasa
# Processing Record 30 of Set 3 | dauphin
# Processing Record 31 of Set 3 | rurrenabaque
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | aksha
# Processing Record 34 of Set 3 | hilo
# Processing Record 35 of Set 3 | airai
# Processing Record 36 of Set 3 | ossora
# Processing Record 37 of Set 3 | talnakh
# Processing Record 38 of Set 3 | miri
# Processing Record 39 of Set 3 | east london
# Processing Record 40 of Set 3 | kalugumalai
# Processing Record 41 of Set 3 | laguna
# Processing Record 42 of Set 3 | saint-francois
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | severo-yeniseyskiy
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | paddhari
# Processing Record 47 of Set 3 | sao gabriel da cachoeira
# Processing Record 48 of Set 3 | morehead
# Processing Record 49 of Set 3 | tuktoyaktuk
# Processing Record 50 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 1 of Set 4 | arraial do cabo
# Processing Record 2 of Set 4 | taguatinga
# Processing Record 3 of Set 4 | ugoofaaru
# Processing Record 4 of Set 4 | puerto baquerizo moreno
# Processing Record 5 of Set 4 | vaitape
# Processing Record 6 of Set 4 | bandarbeyla
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | luis correia
# Processing Record 9 of Set 4 | taoudenni
# Processing Record 10 of Set 4 | port moresby
# Processing Record 11 of Set 4 | hajnowka
# Processing Record 12 of Set 4 | georgetown
# Processing Record 13 of Set 4 | granadilla de abona
# Processing Record 14 of Set 4 | koyelga
# Processing Record 15 of Set 4 | boden
# Processing Record 16 of Set 4 | tsabong
# Processing Record 17 of Set 4 | buin
# Processing Record 18 of Set 4 | avarua
# Processing Record 19 of Set 4 | vostok
# Processing Record 20 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 4 | tazovskiy
# Processing Record 22 of Set 4 | mount gambier
# Processing Record 23 of Set 4 | hun
# Processing Record 24 of Set 4 | singkang
# Processing Record 25 of Set 4 | raga
# Processing Record 26 of Set 4 | fort nelson
# Processing Record 27 of Set 4 | iqaluit
# Processing Record 28 of Set 4 | jishou
# Processing Record 29 of Set 4 | coquimbo
# Processing Record 30 of Set 4 | necochea
# Processing Record 31 of Set 4 | mapiri
# Processing Record 32 of Set 4 | cabedelo
# Processing Record 33 of Set 4 | paucartambo
# City not found. Skipping...
# Processing Record 34 of Set 4 | varnavino
# Processing Record 35 of Set 4 | sabha
# Processing Record 36 of Set 4 | kismayo
# Processing Record 37 of Set 4 | narsaq
# Processing Record 38 of Set 4 | koster
# Processing Record 39 of Set 4 | los llanos de aridane
# Processing Record 40 of Set 4 | saryshagan
# City not found. Skipping...
# Processing Record 41 of Set 4 | ponta do sol
# Processing Record 42 of Set 4 | hurfeish
# Processing Record 43 of Set 4 | geraldton
# Processing Record 44 of Set 4 | saint-augustin
# Processing Record 45 of Set 4 | camargo
# Processing Record 46 of Set 4 | tarut
# Processing Record 47 of Set 4 | new norfolk
# Processing Record 48 of Set 4 | sistranda
# Processing Record 49 of Set 4 | sorong
# Processing Record 50 of Set 4 | flinders
# Processing Record 1 of Set 5 | dingle
# Processing Record 2 of Set 5 | cidreira
# Processing Record 3 of Set 5 | duz
# City not found. Skipping...
# Processing Record 4 of Set 5 | changtu
# Processing Record 5 of Set 5 | imbituba
# Processing Record 6 of Set 5 | camrose
# Processing Record 7 of Set 5 | hutchinson
# Processing Record 8 of Set 5 | tautira
# Processing Record 9 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 5 | saint-pierre
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | hay river
# Processing Record 13 of Set 5 | kavieng
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | omsukchan
# Processing Record 16 of Set 5 | damghan
# Processing Record 17 of Set 5 | kahului
# Processing Record 18 of Set 5 | sumbe
# Processing Record 19 of Set 5 | ouadda
# Processing Record 20 of Set 5 | klaksvik
# Processing Record 21 of Set 5 | plochingen
# Processing Record 22 of Set 5 | bodden town
# Processing Record 23 of Set 5 | kamaishi
# Processing Record 24 of Set 5 | nouakchott
# Processing Record 25 of Set 5 | chabahar
# Processing Record 26 of Set 5 | ladario
# Processing Record 27 of Set 5 | flin flon
# Processing Record 28 of Set 5 | camabatela
# Processing Record 29 of Set 5 | amudat
# Processing Record 30 of Set 5 | vermillion
# Processing Record 31 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 5 | kamenka
# Processing Record 33 of Set 5 | vila do maio
# Processing Record 34 of Set 5 | phonhong
# Processing Record 35 of Set 5 | vila velha
# Processing Record 36 of Set 5 | san vicente
# Processing Record 37 of Set 5 | college
# Processing Record 38 of Set 5 | anori
# Processing Record 39 of Set 5 | hofn
# Processing Record 40 of Set 5 | alice springs
# Processing Record 41 of Set 5 | anloga
# Processing Record 42 of Set 5 | bud
# Processing Record 43 of Set 5 | hegra
# Processing Record 44 of Set 5 | chokurdakh
# Processing Record 45 of Set 5 | bastia
# Processing Record 46 of Set 5 | nioro
# Processing Record 47 of Set 5 | calabozo
# Processing Record 48 of Set 5 | orlik
# Processing Record 49 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 50 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | palmas
# Processing Record 3 of Set 6 | haimen
# Processing Record 4 of Set 6 | cockburn harbour
# City not found. Skipping...
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | charters towers
# Processing Record 7 of Set 6 | chifeng
# Processing Record 8 of Set 6 | jacareacanga
# Processing Record 9 of Set 6 | bilma
# Processing Record 10 of Set 6 | isangel
# Processing Record 11 of Set 6 | mocuba
# Processing Record 12 of Set 6 | mirzapur
# Processing Record 13 of Set 6 | kaitangata
# Processing Record 14 of Set 6 | champerico
# Processing Record 15 of Set 6 | plaisance-du-touch
# Processing Record 16 of Set 6 | bonfim
# Processing Record 17 of Set 6 | acapulco
# Processing Record 18 of Set 6 | crotone
# Processing Record 19 of Set 6 | naze
# Processing Record 20 of Set 6 | ca mau
# Processing Record 21 of Set 6 | bambous virieux
# Processing Record 22 of Set 6 | krasnozerskoye
# Processing Record 23 of Set 6 | marsh harbour
# Processing Record 24 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 25 of Set 6 | paciran
# Processing Record 26 of Set 6 | sept-iles
# Processing Record 27 of Set 6 | saskylakh
# Processing Record 28 of Set 6 | ginda
# Processing Record 29 of Set 6 | ayr
# Processing Record 30 of Set 6 | the pas
# Processing Record 31 of Set 6 | fortin
# City not found. Skipping...
# Processing Record 32 of Set 6 | ahuimanu
# Processing Record 33 of Set 6 | gravelbourg
# Processing Record 34 of Set 6 | ochakiv
# Processing Record 35 of Set 6 | padang
# Processing Record 36 of Set 6 | altay
# Processing Record 37 of Set 6 | kendari
# Processing Record 38 of Set 6 | lata
# Processing Record 39 of Set 6 | beringovskiy
# Processing Record 40 of Set 6 | pahrump
# Processing Record 41 of Set 6 | carnarvon
# Processing Record 42 of Set 6 | codrington
# Processing Record 43 of Set 6 | inhambane
# Processing Record 44 of Set 6 | ambagarh chauki
# Processing Record 45 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 6 | sakaiminato
# Processing Record 47 of Set 6 | dryden
# Processing Record 48 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 49 of Set 6 | sedalia
# Processing Record 50 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 7 | gizo
# Processing Record 2 of Set 7 | omboue
# Processing Record 3 of Set 7 | katsuura
# Processing Record 4 of Set 7 | kalmar
# Processing Record 5 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 6 of Set 7 | krivosheino
# Processing Record 7 of Set 7 | talcahuano
# Processing Record 8 of Set 7 | inta
# Processing Record 9 of Set 7 | maceio
# Processing Record 10 of Set 7 | muroto
# Processing Record 11 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 7 | sawakin
# Processing Record 13 of Set 7 | christchurch
# Processing Record 14 of Set 7 | banda aceh
# Processing Record 15 of Set 7 | marsa matruh
# Processing Record 16 of Set 7 | matamoros
# Processing Record 17 of Set 7 | podgorodnyaya pokrovka
# Processing Record 18 of Set 7 | santa maria
# Processing Record 19 of Set 7 | kieta
# Processing Record 20 of Set 7 | jurado
# Processing Record 21 of Set 7 | diego de almagro
# Processing Record 22 of Set 7 | along
# Processing Record 23 of Set 7 | samarai
# Processing Record 24 of Set 7 | coihaique
# Processing Record 25 of Set 7 | kununurra
# Processing Record 26 of Set 7 | husavik
# Processing Record 27 of Set 7 | pangnirtung
# Processing Record 28 of Set 7 | yellowknife
# Processing Record 29 of Set 7 | dakoro
# Processing Record 30 of Set 7 | sillod
# Processing Record 31 of Set 7 | yumen
# Processing Record 32 of Set 7 | buraydah
# Processing Record 33 of Set 7 | fougeres
# Processing Record 34 of Set 7 | aksarka
# Processing Record 35 of Set 7 | mantua
# Processing Record 36 of Set 7 | newberry
# Processing Record 37 of Set 7 | magadan
# Processing Record 38 of Set 7 | dujuma
# City not found. Skipping...
# Processing Record 39 of Set 7 | tolaga bay
# Processing Record 40 of Set 7 | bacuit
# City not found. Skipping...
# Processing Record 41 of Set 7 | miandrivazo
# Processing Record 42 of Set 7 | plouzane
# Processing Record 43 of Set 7 | columbus
# Processing Record 44 of Set 7 | ahipara
# Processing Record 45 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 7 | punta alta
# Processing Record 47 of Set 7 | baft
# Processing Record 48 of Set 7 | xichang
# Processing Record 49 of Set 7 | ostrovnoy
# Processing Record 50 of Set 7 | fairbanks
# Processing Record 1 of Set 8 | marmarion
# Processing Record 2 of Set 8 | leningradskiy
# Processing Record 3 of Set 8 | quelimane
# Processing Record 4 of Set 8 | sao filipe
# Processing Record 5 of Set 8 | bathsheba
# Processing Record 6 of Set 8 | evensk
# Processing Record 7 of Set 8 | makakilo city
# Processing Record 8 of Set 8 | port-cartier
# Processing Record 9 of Set 8 | elat
# Processing Record 10 of Set 8 | tual
# Processing Record 11 of Set 8 | grahamstown
# Processing Record 12 of Set 8 | luangwa
# Processing Record 13 of Set 8 | vanimo
# Processing Record 14 of Set 8 | alyangula
# Processing Record 15 of Set 8 | bozova
# Processing Record 16 of Set 8 | tabialan
# City not found. Skipping...
# Processing Record 17 of Set 8 | san patricio
# Processing Record 18 of Set 8 | deputatskiy
# Processing Record 19 of Set 8 | monki
# Processing Record 20 of Set 8 | apatin
# Processing Record 21 of Set 8 | ocos
# Processing Record 22 of Set 8 | iquitos
# Processing Record 23 of Set 8 | harper
# Processing Record 24 of Set 8 | maputo
# Processing Record 25 of Set 8 | sibenik
# Processing Record 26 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 8 | ilulissat
# Processing Record 28 of Set 8 | covington
# Processing Record 29 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 8 | multan
# Processing Record 31 of Set 8 | baykit
# Processing Record 32 of Set 8 | sisimiut
# Processing Record 33 of Set 8 | tortoli
# Processing Record 34 of Set 8 | coruripe
# Processing Record 35 of Set 8 | trat
# Processing Record 36 of Set 8 | abiy adi
# City not found. Skipping...
# Processing Record 37 of Set 8 | mareeba
# Processing Record 38 of Set 8 | the valley
# Processing Record 39 of Set 8 | marica
# Processing Record 40 of Set 8 | robertsport
# Processing Record 41 of Set 8 | panji
# Processing Record 42 of Set 8 | eureka
# Processing Record 43 of Set 8 | chinsali
# Processing Record 44 of Set 8 | solnechnyy
# Processing Record 45 of Set 8 | chestermere
# Processing Record 46 of Set 8 | prince rupert
# Processing Record 47 of Set 8 | niagara falls
# Processing Record 48 of Set 8 | russell
# Processing Record 49 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 50 of Set 8 | port macquarie
# Processing Record 1 of Set 9 | vao
# Processing Record 2 of Set 9 | bengkulu
# Processing Record 3 of Set 9 | veracruz
# Processing Record 4 of Set 9 | sangar
# Processing Record 5 of Set 9 | luyang
# Processing Record 6 of Set 9 | karratha
# Processing Record 7 of Set 9 | goundam
# Processing Record 8 of Set 9 | abu samrah
# Processing Record 9 of Set 9 | ambilobe
# Processing Record 10 of Set 9 | sadove
# Processing Record 11 of Set 9 | mount isa
# Processing Record 12 of Set 9 | suluq
# Processing Record 13 of Set 9 | lavrentiya
# Processing Record 14 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 15 of Set 9 | thunder bay
# Processing Record 16 of Set 9 | viedma
# Processing Record 17 of Set 9 | vardo
# Processing Record 18 of Set 9 | pozzallo
# Processing Record 19 of Set 9 | erenhot
# Processing Record 20 of Set 9 | manokwari
# Processing Record 21 of Set 9 | yulara
# Processing Record 22 of Set 9 | kirovskiy
# Processing Record 23 of Set 9 | mahebourg
# Processing Record 24 of Set 9 | aklavik
# Processing Record 25 of Set 9 | kharp
# Processing Record 26 of Set 9 | ayagoz
# Processing Record 27 of Set 9 | krasnoselkup
# Processing Record 28 of Set 9 | ancud
# Processing Record 29 of Set 9 | gritsovskiy
# Processing Record 30 of Set 9 | nome
# Processing Record 31 of Set 9 | kailua
# Processing Record 32 of Set 9 | lulea
# Processing Record 33 of Set 9 | vila franca do campo
# Processing Record 34 of Set 9 | waipawa
# Processing Record 35 of Set 9 | hamilton
# Processing Record 36 of Set 9 | henties bay
# Processing Record 37 of Set 9 | muisne
# Processing Record 38 of Set 9 | sinnamary
# Processing Record 39 of Set 9 | alcaniz
# Processing Record 40 of Set 9 | vestmanna
# Processing Record 41 of Set 9 | wamba
# Processing Record 42 of Set 9 | kloulklubed
# Processing Record 43 of Set 9 | santa lucia
# Processing Record 44 of Set 9 | te anau
# Processing Record 45 of Set 9 | mugango
# Processing Record 46 of Set 9 | saint-medard-en-jalles
# Processing Record 47 of Set 9 | mopti
# Processing Record 48 of Set 9 | grande-riviere
# City not found. Skipping...
# Processing Record 49 of Set 9 | port lincoln
# Processing Record 50 of Set 9 | nepalganj
# City not found. Skipping...
# Processing Record 1 of Set 10 | paamiut
# Processing Record 2 of Set 10 | canmore
# Processing Record 3 of Set 10 | sabang
# Processing Record 4 of Set 10 | gigmoto
# Processing Record 5 of Set 10 | razdolnoye
# Processing Record 6 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 10 | shaoguan
# Processing Record 8 of Set 10 | staryy nadym
# Processing Record 9 of Set 10 | poyarkovo
# Processing Record 10 of Set 10 | arica
# Processing Record 11 of Set 10 | whitianga
# Processing Record 12 of Set 10 | chumphon
# Processing Record 13 of Set 10 | porto novo
# Processing Record 14 of Set 10 | rio gallegos
# Processing Record 15 of Set 10 | shetpe
# Processing Record 16 of Set 10 | corowa
# Processing Record 17 of Set 10 | panama city
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | raudeberg
# Processing Record 20 of Set 10 | preveza
# Processing Record 21 of Set 10 | ojinaga
# Processing Record 22 of Set 10 | green river
# Processing Record 23 of Set 10 | muzhi
# Processing Record 24 of Set 10 | springfield
# Processing Record 25 of Set 10 | beckley
# Processing Record 26 of Set 10 | camden
# Processing Record 27 of Set 10 | asau
# Processing Record 28 of Set 10 | aksu
# Processing Record 29 of Set 10 | ashqelon
# Processing Record 30 of Set 10 | marzuq
# Processing Record 31 of Set 10 | koroni
# Processing Record 32 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 33 of Set 10 | torbay
# Processing Record 34 of Set 10 | petrolina
# Processing Record 35 of Set 10 | tamworth
# Processing Record 36 of Set 10 | saint-joseph
# Processing Record 37 of Set 10 | birjand
# Processing Record 38 of Set 10 | palabuhanratu
# City not found. Skipping...
# Processing Record 39 of Set 10 | inyonga
# Processing Record 40 of Set 10 | lorengau
# Processing Record 41 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 42 of Set 10 | malie
# Processing Record 43 of Set 10 | verdalsora
# City not found. Skipping...
# Processing Record 44 of Set 10 | komsomolskiy
# Processing Record 45 of Set 10 | agadez
# Processing Record 46 of Set 10 | nantucket
# Processing Record 47 of Set 10 | aden
# Processing Record 48 of Set 10 | noumea
# Processing Record 49 of Set 10 | kapoeta
# Processing Record 50 of Set 10 | anage
# Processing Record 1 of Set 11 | kurchum
# Processing Record 2 of Set 11 | brazzaville
# Processing Record 3 of Set 11 | alugan
# Processing Record 4 of Set 11 | uglegorskiy
# Processing Record 5 of Set 11 | manaus
# Processing Record 6 of Set 11 | abatskoye
# Processing Record 7 of Set 11 | faya
# Processing Record 8 of Set 11 | senmonorom
# City not found. Skipping...
# Processing Record 9 of Set 11 | kolvereid
# Processing Record 10 of Set 11 | el cobre
# Processing Record 11 of Set 11 | kavaratti
# Processing Record 12 of Set 11 | tiznit
# Processing Record 13 of Set 11 | jiangyou
# Processing Record 14 of Set 11 | boende
# Processing Record 15 of Set 11 | solenzo
# Processing Record 16 of Set 11 | bloomsburg
# Processing Record 17 of Set 11 | beitbridge
# Processing Record 18 of Set 11 | neiafu
# Processing Record 19 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 11 | maldonado
# Processing Record 21 of Set 11 | svetlogorsk
# Processing Record 22 of Set 11 | gravdal
# Processing Record 23 of Set 11 | anaconda
# Processing Record 24 of Set 11 | sao joao da barra
# Processing Record 25 of Set 11 | ankang
# Processing Record 26 of Set 11 | toliary
# City not found. Skipping...
# Processing Record 27 of Set 11 | ruteng
# Processing Record 28 of Set 11 | strangnas
# Processing Record 29 of Set 11 | san andres
# Processing Record 30 of Set 11 | broome
# Processing Record 31 of Set 11 | misratah
# Processing Record 32 of Set 11 | baisha
# Processing Record 33 of Set 11 | tabas
# Processing Record 34 of Set 11 | vrangel
# Processing Record 35 of Set 11 | almeria
# Processing Record 36 of Set 11 | lagoa
# Processing Record 37 of Set 11 | rock springs
# Processing Record 38 of Set 11 | aasiaat
# Processing Record 39 of Set 11 | touros
# Processing Record 40 of Set 11 | cuenca
# Processing Record 41 of Set 11 | teguise
# Processing Record 42 of Set 11 | ballitoville
# Processing Record 43 of Set 11 | leua
# Processing Record 44 of Set 11 | havre-saint-pierre
# Processing Record 45 of Set 11 | roald
# Processing Record 46 of Set 11 | almeirim
# Processing Record 47 of Set 11 | rezekne
# Processing Record 48 of Set 11 | rawson
# Processing Record 49 of Set 11 | tommot
# Processing Record 50 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 12 | latung
# Processing Record 2 of Set 12 | bako
# Processing Record 3 of Set 12 | oranjestad
# Processing Record 4 of Set 12 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 12 | abu dhabi
# Processing Record 6 of Set 12 | huarmey
# Processing Record 7 of Set 12 | adrar
# Processing Record 8 of Set 12 | urshelskiy
# Processing Record 9 of Set 12 | pemangkat
# Processing Record 10 of Set 12 | trairi
# Processing Record 11 of Set 12 | alabaster
# Processing Record 12 of Set 12 | kristiinankaupunki
# Processing Record 13 of Set 12 | beidao
# Processing Record 14 of Set 12 | hopelchen
# Processing Record 15 of Set 12 | rocha
# Processing Record 16 of Set 12 | opuwo
# Processing Record 17 of Set 12 | lerwick
# Processing Record 18 of Set 12 | chipiona
# Processing Record 19 of Set 12 | praia da vitoria
# Processing Record 20 of Set 12 | atar
# Processing Record 21 of Set 12 | humaita
# Processing Record 22 of Set 12 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 23 of Set 12 | maamba
# Processing Record 24 of Set 12 | birao
# Processing Record 25 of Set 12 | siocon
# Processing Record 26 of Set 12 | aracati
# Processing Record 27 of Set 12 | fortuna
# Processing Record 28 of Set 12 | bakchar
# Processing Record 29 of Set 12 | luwingu
# Processing Record 30 of Set 12 | berbera
# Processing Record 31 of Set 12 | clovis
# Processing Record 32 of Set 12 | kinston
# Processing Record 33 of Set 12 | churapcha
# Processing Record 34 of Set 12 | arman
# Processing Record 35 of Set 12 | vangaindrano
# Processing Record 36 of Set 12 | honiara
# Processing Record 37 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 38 of Set 12 | qarchak
# Processing Record 39 of Set 12 | balikpapan
# Processing Record 40 of Set 12 | melhus
# Processing Record 41 of Set 12 | lisala
# Processing Record 42 of Set 12 | envira
# Processing Record 43 of Set 12 | kudahuvadhoo
# Processing Record 44 of Set 12 | balkhash
# Processing Record 45 of Set 12 | el faiyum
# City not found. Skipping...
# Processing Record 46 of Set 12 | yurla
# Processing Record 47 of Set 12 | labuhan
# Processing Record 48 of Set 12 | acajutla
# Processing Record 49 of Set 12 | sur
# Processing Record 50 of Set 12 | mackay
# Processing Record 1 of Set 13 | la ronge
# Processing Record 2 of Set 13 | hobyo
# Processing Record 3 of Set 13 | los alamos
# Processing Record 4 of Set 13 | keti bandar
# Processing Record 5 of Set 13 | caraballeda
# Processing Record 6 of Set 13 | rassvet
# Processing Record 7 of Set 13 | changji
# Processing Record 8 of Set 13 | tuatapere
# Processing Record 9 of Set 13 | gogrial
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | zavyalovo
# Processing Record 12 of Set 13 | ormara
# Processing Record 13 of Set 13 | abalak
# Processing Record 14 of Set 13 | mairana
# Processing Record 15 of Set 13 | pacific grove
# Processing Record 16 of Set 13 | guantanamo
# Processing Record 17 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 13 | menongue
# Processing Record 19 of Set 13 | kenai
# Processing Record 20 of Set 13 | provost
# Processing Record 21 of Set 13 | aykhal
# Processing Record 22 of Set 13 | thinadhoo
# Processing Record 23 of Set 13 | capreol
# Processing Record 24 of Set 13 | luanda
# Processing Record 25 of Set 13 | emirdag
# Processing Record 26 of Set 13 | jitia
# Processing Record 27 of Set 13 | novobessergenevka
# Processing Record 28 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 13 | itarema
# Processing Record 30 of Set 13 | deloraine
# Processing Record 31 of Set 13 | sechura
# Processing Record 32 of Set 13 | phangnga
# Processing Record 33 of Set 13 | brownsville
# Processing Record 34 of Set 13 | kolno
# Processing Record 35 of Set 13 | bosaso
# Processing Record 36 of Set 13 | saiha
# Processing Record 37 of Set 13 | teya
# Processing Record 38 of Set 13 | constitucion
# Processing Record 39 of Set 13 | sigli
# Processing Record 40 of Set 13 | qasigiannguit
# Processing Record 41 of Set 13 | oktyabrskiy
# Processing Record 42 of Set 13 | esperance
# Processing Record 43 of Set 13 | wagar
# Processing Record 44 of Set 13 | baiao
# Processing Record 45 of Set 13 | lyangasovo
# Processing Record 46 of Set 13 | xuddur
# Processing Record 47 of Set 13 | alta
# Processing Record 48 of Set 13 | svetlyy
# Processing Record 49 of Set 13 | matara
# Processing Record 50 of Set 13 | natal
# Processing Record 1 of Set 14 | prieska
# Processing Record 2 of Set 14 | piacabucu
# Processing Record 3 of Set 14 | carballo
# Processing Record 4 of Set 14 | santa cruz de la palma
# Processing Record 5 of Set 14 | kosa
# Processing Record 6 of Set 14 | anandpur sahib
# Processing Record 7 of Set 14 | biharamulo
# Processing Record 8 of Set 14 | tevaitoa
# Processing Record 9 of Set 14 | ketchikan
# Processing Record 10 of Set 14 | uchaly
# Processing Record 11 of Set 14 | usinsk
# Processing Record 12 of Set 14 | ponnani
# Processing Record 13 of Set 14 | rayadrug
# Processing Record 14 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 14 | norman wells
# Processing Record 16 of Set 14 | yeppoon
# Processing Record 17 of Set 14 | waingapu
# Processing Record 18 of Set 14 | mumford
# Processing Record 19 of Set 14 | coahuayana
# Processing Record 20 of Set 14 | blonduos
# City not found. Skipping...
# Processing Record 21 of Set 14 | sohag
# Processing Record 22 of Set 14 | dores do indaia
# Processing Record 23 of Set 14 | kupang
# Processing Record 24 of Set 14 | irece
# Processing Record 25 of Set 14 | baghdad
# Processing Record 26 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 14 | takoradi
# Processing Record 28 of Set 14 | hambantota
# Processing Record 29 of Set 14 | malatya
# Processing Record 30 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 14 | zhangjiakou
# Processing Record 32 of Set 14 | alpena
# Processing Record 33 of Set 14 | hami
# Processing Record 34 of Set 14 | kalabo
# Processing Record 35 of Set 14 | moussoro
# Processing Record 36 of Set 14 | san francisco
# Processing Record 37 of Set 14 | chino valley
# Processing Record 38 of Set 14 | devils lake
# Processing Record 39 of Set 14 | rudsar
# Processing Record 40 of Set 14 | cam ranh
# Processing Record 41 of Set 14 | rogovatoye
# Processing Record 42 of Set 14 | chikmagalur
# Processing Record 43 of Set 14 | balabac
# Processing Record 44 of Set 14 | remontnoye
# Processing Record 45 of Set 14 | marienburg
# Processing Record 46 of Set 14 | sabaudia
# Processing Record 47 of Set 14 | yar-sale
# Processing Record 48 of Set 14 | sioux lookout
# Processing Record 49 of Set 14 | riyadh
# Processing Record 50 of Set 14 | betare oya
# Processing Record 1 of Set 15 | marfino
# Processing Record 2 of Set 15 | jumla
# Processing Record 3 of Set 15 | lisakovsk
# Processing Record 4 of Set 15 | nambucca heads
# Processing Record 5 of Set 15 | coxim
# Processing Record 6 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 7 of Set 15 | farafangana
# Processing Record 8 of Set 15 | rantepao
# Processing Record 9 of Set 15 | iralaya
# Processing Record 10 of Set 15 | bubaque
# Processing Record 11 of Set 15 | dianopolis
# City not found. Skipping...
# Processing Record 12 of Set 15 | resistencia
# Processing Record 13 of Set 15 | ibra
# Processing Record 14 of Set 15 | lima
# Processing Record 15 of Set 15 | bonthe
# Processing Record 16 of Set 15 | dicabisagan
# Processing Record 17 of Set 15 | klichka
# Processing Record 18 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 19 of Set 15 | beira
# Processing Record 20 of Set 15 | kirakira
# Processing Record 21 of Set 15 | ngunguru
# Processing Record 22 of Set 15 | ballina
# Processing Record 23 of Set 15 | thabazimbi
# Processing Record 24 of Set 15 | nemuro
# Processing Record 25 of Set 15 | parabel
# Processing Record 26 of Set 15 | pangody
# Processing Record 27 of Set 15 | djenne
# Processing Record 28 of Set 15 | lalomanu
# City not found. Skipping...
# Processing Record 29 of Set 15 | maues
# Processing Record 30 of Set 15 | milkovo
# Processing Record 31 of Set 15 | palmer
# Processing Record 32 of Set 15 | terrasini
# Processing Record 33 of Set 15 | soria
# Processing Record 34 of Set 15 | hualmay
# Processing Record 35 of Set 15 | ust-tsilma
# Processing Record 36 of Set 15 | angra
# City not found. Skipping...
# Processing Record 37 of Set 15 | poum
# Processing Record 38 of Set 15 | port-gentil
# Processing Record 39 of Set 15 | finschhafen
# Processing Record 40 of Set 15 | masakin
# Processing Record 41 of Set 15 | kontagora
# Processing Record 42 of Set 15 | guarapari
# Processing Record 43 of Set 15 | zhicheng
# Processing Record 44 of Set 15 | vargashi
# Processing Record 45 of Set 15 | naples
# Processing Record 46 of Set 15 | kropotkin
# Processing Record 47 of Set 15 | nishihara
# Processing Record 48 of Set 15 | polunochnoye
# Processing Record 49 of Set 15 | cap malheureux
# Processing Record 50 of Set 15 | la primavera
# Processing Record 1 of Set 16 | namtsy
# Processing Record 2 of Set 16 | marsaxlokk
# Processing Record 3 of Set 16 | urgut
# Processing Record 4 of Set 16 | melbu
# Processing Record 5 of Set 16 | nogliki
# Processing Record 6 of Set 16 | cozumel
# Processing Record 7 of Set 16 | wahran
# City not found. Skipping...
# Processing Record 8 of Set 16 | rongcheng
# Processing Record 9 of Set 16 | bairiki
# Processing Record 10 of Set 16 | tutoia
# Processing Record 11 of Set 16 | roman
# Processing Record 12 of Set 16 | marsta
# Processing Record 13 of Set 16 | mokhsogollokh
# Processing Record 14 of Set 16 | jiayuguan
# Processing Record 15 of Set 16 | kampot
# Processing Record 16 of Set 16 | berdigestyakh
# Processing Record 17 of Set 16 | batemans bay
# Processing Record 18 of Set 16 | pemba
# Processing Record 19 of Set 16 | moree
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Guerrero Negro      MX  27.9769 -114.0611     85.46        42          81
# 1          Chatra      IN  24.2167   84.8667     73.38        91          93
# 2       Wanlaweyn      SO   2.6185   44.8938     76.75        80          24
# 3          Mehamn      NO  71.0357   27.8492     53.51        72         100
# 4        Khatanga      RU  71.9667  102.5000     19.26        93          99
# 5   Mar Del Plata      AR -38.0023  -57.5575     51.01        58           0
# 6        Hermanus      ZA -34.4187   19.2345     52.90        71          60
# 7        Victoria      HK  22.2855  114.1577     84.33        81          88
# 8         Mataura      NZ -46.1927  168.8643     48.47        83         100
# 9      Pleshanovo      RU  52.8333   53.4833     46.29        73         100
#
#    Wind Speed Current Description
# 0       10.78       broken clouds
# 1        3.51     overcast clouds
# 2       11.43          few clouds
# 3       32.17     overcast clouds
# 4       12.68     overcast clouds
# 5       13.00           clear sky
# 6        9.71          light rain
# 7        1.99     overcast clouds
# 8        8.55          light rain
# 9        7.58     overcast clouds

# %% [markdown]
# ### Create CSV output file

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
